# %% [markdown]
# # Evaluación I
# ## Evaluación de contenidos 1 Módulo 2
# Bienvenidas a una nueva evaluación del Bootcamp de Análisis de Datos de Adalab.
# Como en evaluaciones anteriores dispondréis de 2 tardes (aproximadamente 8 horas para la resolución de todos los ejercicios propuestos).
# Estos ejercicios se tendrán que defender en el día de la evaluación de forma individual con vuestra tutora en una simulación de entrevista técnica donde tendréis de 20 minutos para resolver o explicar los ejercicios propuestos entregados.
#
# ## Ejercicios de NumPy
#
#     1. Importa la librería de NumPy.

# %%
import numpy as np

# %% [markdown]
#     2. Crea un array de 1 dimension y 10 elementos.

# %%
arr1 = np.random.randint(100,1000, (10))
arr1
# Out:
# array([880, 434, 520, 660, 466, 552, 184, 709, 608, 855])

# %% [markdown]
#     3. Reemplaza todos los números impares por el valor "impar" y los pares por "par". Para hacer esto os tendréis que crear un array nuevo donde vayáis añadiendo los valores nuevos.

# %%
arr2 = np.empty_like(arr1, dtype = object ) #creamos un array con las mismas características que el anterior
arr2
# Out:
# array([None, None, None, None, None, None, None, None, None, None],
#       dtype=object)

# %%
for i in range(0, arr1.shape[0]):
    if arr1[i]%2 == 0:
        arr2[i] = "par"
    elif arr1[i]%2 != 0:
        arr2[i] = "impar"

# %%
arr2
# Out:
# array(['par', 'par', 'par', 'par', 'par', 'par', 'par', 'impar', 'par',
#        'impar'], dtype=object)

# %% [markdown]
#     4. Cambiad la forma del array del ejercicio 3 a un array de 2 filas y 5 columnas.

# %%
arr3 = np.reshape(arr2, (2,5))
arr3
# Out:
# array([['par', 'par', 'par', 'par', 'par'],
#        ['par', 'par', 'impar', 'par', 'impar']], dtype=object)

# %% [markdown]
#     5. Extrae los elementos comunes de los siguientes arrays
#         array1 = np.array([1,2,3,2,3,4,3,4,5,6])
#         array2 = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
array1 = np.array([1,2,3,2,3,4,3,4,5,6])
array2 = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
array3 = np.intersect1d(array1, array2)
array3
# Out:
# array([2, 4])

# %% [markdown]
#     6. Extraed los elementos que están en el array1 pero no en el array2.

# %%
array4 = np.setdiff1d(array1, array2)
array4
# Out:
# array([1, 3, 5, 6])

# %% [markdown]
#     7. Extraed las posiciones donde tengamos elementos que sean iguales.

# %%
array1 = np.array([1,2,3,2,3,4,3,4,5,6])
array2 = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
posiciones = np.where(array1 == array2)

# %%
print(f"las posiciones del array2 donde se encuentran los elementos comunes del array1 son :", posiciones)
# Out:
# las posiciones del array2 donde se encuentran los elementos comunes del array1 son : (array([1, 3, 5, 7]),)

# %% [markdown]
#     8. Cread un array de 3 filas y 5 columnas, con números enteros del 0 al 50. Una vez creado, extrae los valores que sean menores que 10 y mayores que 40.

# %%
arr4 = np.random.randint(0,50, (3,5))
arr4
# Out:
# array([[ 2, 15, 40, 36,  0],
#        [38,  1,  0, 38, 44],
#        [44, 46, 25, 40, 10]])

# %%
valores = arr4[(arr4 < 10) | (arr4 > 40)]
valores
# Out:
# array([ 2,  0,  1,  0, 44, 44, 46])

# %% [markdown]
#     9. Cread un array de 5x3 con números decimales aleatorios entre el 5 y el 10.

# %%
arr5 = np.random.uniform(5, 10, (5,3))
arr5
# Out:
# array([[7.29658279, 5.71127824, 6.44574103],
#        [7.97781322, 6.91810806, 9.03923392],
#        [5.07033729, 5.03896676, 6.28264112],
#        [6.43814101, 9.50497875, 8.03636489],
#        [5.30130751, 9.78250088, 8.93116376]])

# %% [markdown]
#     10. Crea un array de tres dimensiones de 2x4x7 con números entre el 1 y el 20

# %%
arr6 = np.random.randint(1, 20, (2,4,7))
arr6
# Out:
# array([[[ 8, 10, 12,  5,  3,  8, 19],
#         [ 5, 10,  7,  7,  8, 12, 14],
#         [19,  5,  4,  1,  3, 15,  5],
#         [11, 11, 19, 15,  4,  8, 10]],
#
#        [[17, 14, 18, 11,  5,  5, 11],
#         [19,  6, 15, 12,  3,  1, 15],
#         [15,  7,  7, 19, 18,  5, 13],
#         [11,  8,  5, 11, 19, 16, 12]]])

# %% [markdown]
#         10.1 Transponed el array para que tenga 4 matrices, 7 filas y 2 columnas

# %%
arr7 = np.reshape(arr6, (4,7,2))
arr8 = np.transpose(arr6, (1,2,0))
arr7
# Out:
# array([[[ 8, 10],
#         [12,  5],
#         [ 3,  8],
#         [19,  5],
#         [10,  7],
#         [ 7,  8],
#         [12, 14]],
#
#        [[19,  5],
#         [ 4,  1],
#         [ 3, 15],
#         [ 5, 11],
#         [11, 19],
#         [15,  4],
#         [ 8, 10]],
#
#        [[17, 14],
#         [18, 11],
#         [ 5,  5],
#         [11, 19],
#         [ 6, 15],
#         [12,  3],
#         [ 1, 15]],
#
#        [[15,  7],
#         [ 7, 19],
#         [18,  5],
#         [13, 11],
#         [ 8,  5],
#         [11, 19],
#         [16, 12]]])

# %%
arr8
# Out:
# array([[[ 8, 17],
#         [10, 14],
#         [12, 18],
#         [ 5, 11],
#         [ 3,  5],
#         [ 8,  5],
#         [19, 11]],
#
#        [[ 5, 19],
#         [10,  6],
#         [ 7, 15],
#         [ 7, 12],
#         [ 8,  3],
#         [12,  1],
#         [14, 15]],
#
#        [[19, 15],
#         [ 5,  7],
#         [ 4,  7],
#         [ 1, 19],
#         [ 3, 18],
#         [15,  5],
#         [ 5, 13]],
#
#        [[11, 11],
#         [11,  8],
#         [19,  5],
#         [15, 11],
#         [ 4, 19],
#         [ 8, 16],
#         [10, 12]]])

# %% [markdown]
# ## Ejercicios de Pandas
#
# Para la parte de Pandas usaremos el mismo conjunto de datos de música de Spotify, en concreto tendremos un conjunto de datos de canciones de varios artistas en el mundo y para cada canción está presente:
# - Varias estadísticas de la versión musical en spotify, incluido el número de streams;
# - Número de visualizaciones del vídeo musical oficial de la canción en youtube.
#
# Las variables que tendremos en este dataframe son:
#
# Incluye 26 variables para cada una de las canciones recogidas de spotify. Estas variables se describen brevemente a continuación:
# - Track: nombre de la canción, tal y como aparece en la plataforma Spotify.
# - Artist: nombre del artista.
# - Url_spotify: Url de la canción.
# - Album: el álbum en el que se encuentra la canción en Spotify.
# - Album_type: indica si la canción se publica en Spotify como single o dentro de un álbum.
# - Uri: un enlace de Spotify utilizado para encontrar la canción a través de la API.
# - Danceability: describe lo adecuada que es una canción para bailar basándose en una combinación de elementos musicales como el tempo, la estabilidad del ritmo, la fuerza del compás y la regularidad general. Un valor de 0,0 es el menos bailable y 1,0 el más bailable.
# - Energy: es una medida de 0,0 a 1,0 y representa una medida perceptiva de intensidad y actividad. Normalmente, las pistas energéticas son rápidas, ruidosas y ruidosas. Por ejemplo, el death metal tiene mucha energía, mientras que un preludio de Bach tiene una puntuación baja en la escala. Las características perceptivas que contribuyen a este atributo incluyen el rango dinámico, el volumen percibido, el timbre, la velocidad de inicio y la entropía general.
# - Key: la clave de la pista. Los números enteros se asignan a los tonos utilizando la notación estándar Pitch Class. Por ejemplo, 0 = C, 1 = C♯/D♭, 2 = D, y así sucesivamente. Si no se detecta ninguna tonalidad, el valor es -1.
# - Loudness: la sonoridad global de una pista en decibelios (dB). Los valores de sonoridad se promedian en toda la pista y son útiles para comparar la sonoridad relativa de las pistas. La sonoridad es la cualidad de un sonido que es el principal correlato psicológico de la fuerza física (amplitud). Los valores suelen oscilar entre -60 y 0 db.
# - Speechiness: detecta la presencia de palabras habladas en una pista. Cuanto más exclusivamente hablada sea la grabación (por ejemplo, un programa de entrevistas, un audiolibro, poesía), más se acercará a 1,0 el valor del atributo. Los valores superiores a 0,66 describen pistas que probablemente estén compuestas en su totalidad por palabras habladas. Los valores entre 0,33 y 0,66 describen pistas que pueden contener tanto música como voz, ya sea en secciones o en capas, incluyendo casos como la música rap. Los valores por debajo de 0,33 representan probablemente música y otras pistas no habladas.
# - Acousticness: una medida de confianza de 0,0 a 1,0 para determinar si la pista es acústica. 1,0 representa una confianza alta en que la pista es acústica.
# Instrumentalness: predice si una pista no contiene voces. Los sonidos "ooh" y "aah" se consideran instrumentales en este contexto. Las pistas de rap o spoken word son claramente "vocales". Cuanto más se acerque el valor de instrumental a 1,0, mayor será la probabilidad de que la canción no contenga voces. Los valores superiores a 0,5 representan pistas instrumentales, pero la confianza es mayor a medida que el valor se acerca a 1,0.
# - Liveness: detecta la presencia de público en la grabación. Los valores más altos representan una mayor probabilidad de que la pista se haya interpretado en directo. Un valor superior a 0,8 proporciona una gran probabilidad de que la pista sea en directo.
# - Valence: una medida de 0,0 a 1,0 que describe la positividad musical que transmite una pista. Las pistas con una valencia alta suenan más positivas (por ejemplo, felices, alegres, eufóricas), mientras que las pistas con una valencia baja suenan más negativas (por ejemplo, tristes, deprimidas, enfadadas).
# - Tempo: el tempo global estimado de una pista en pulsaciones por minuto (BPM). En terminología musical, el tempo es la velocidad o el ritmo de una pieza determinada y se deriva directamente de la duración media de los tiempos.
# - Duration_ms: duración de la pista en milisegundos.
# - Stream: número de streams de la canción en Spotify.
# - Url_youtube: url del vídeo enlazado a la canción en Youtube, si lo tiene.
# - Title: título del videoclip en Youtube.
# - Channel: nombre del canal que ha publicado el vídeo.
# - Views: número de vistas.
# - Likes: número de me gusta.
# - Comments: número de comentarios.
# - Description: descripción del vídeo en Youtube.
# - Licensed: Indica si el vídeo representa contenido con licencia, lo que significa que el contenido fue subido a un canal vinculado a un socio de contenido de Youtube y luego reclamado por dicho socio.
# - official_video: valor booleano que indica si el vídeo encontrado es el vídeo oficial de la canción.

# %% [markdown]
# ### Los ejercicios que os plantemos para esta parte de la evaluación son:
#
#     1. Importad Pandas

# %%
import pandas as pd

# %% [markdown]
#     2. Exploración del conjunto de datos:
#         2.1. Cargad el fichero, al cargarlo os aparecerá una columna llamada "Unnamed: 0". Cargad el dataset sin que aparezca esta columna. Además realizad un análisis exploratorio que incluya:

# %%
df = pd.read_csv("Spotify_Youtube.csv", index_col = 0)

# %% [markdown]
#         2.2. Cuando leais el fichero, veremos que no podemos ver todas las columnas, utilizad el comando correcto para poder visualizarlas todas cuando hacemos un head

# %%
pd.options.display.max_columns = None

# %% [markdown]
#         2.3. Primeras 5 filas del dataframe

# %%
df.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
#         2.4. Últimas 5 filas del dataframe

# %%
df.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# ...

# %% [markdown]
#         2.5. 10 filas aleatorias del dataframe

# %%
df.sample(10)
# Out:
#                      Artist  \
# 8341             Jelly Roll
# 15935          Ankit Tiwari
# 16179               Becky G
# 3608            Chuck Berry
# 18518              PnB Rock
# 3531           Wu-Tang Clan
# 10758         Kings of Leon
# 11214          Kailash Kher
# 1716   La Oreja de Van Gogh
# 2852           Hikaru Utada
#
#                                              Url_spotify  \
# 8341   https://open.spotify.com/artist/19k8AgwwTSxeax...
# 15935  https://open.spotify.com/artist/0E02VcvA5p1ndk...
# 16179  https://open.spotify.com/artist/4obzFoKoKRHIph...
# 3608   https://open.spotify.com/artist/293zczrfYafIIt...
# 18518  https://open.spotify.com/artist/21WS9wngs9AqFc...
# 3531   https://open.spotify.com/artist/34EP7KEpOjXcM2...
# 10758  https://open.spotify.com/artist/2qk9voo8llSGYc...
# 11214  https://open.spotify.com/artist/4oVMLzAqW6qhRp...
# 1716   https://open.spotify.com/artist/4U7lXyKdSf1JbM...
# 2852   https://open.spotify.com/artist/7lbSsjYACZHn1M...
#
# ...

# %% [markdown]
#         2.6. ¿Cuántas filas y columnas tenemos en el dataframe

# %%
df.shape
# Out:
# (20718, 27)

# %% [markdown]
#         2.7. ¿Cuáles son los tipos de los datos de cada columna del dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  object
#  7   Energy            20716 non-null  object
#  8   Key               20716 non-null  object
#  9   Loudness          20716 non-null  object
#  10  Speechiness       20716 non-null  object
#  11  Acousticness      20716 non-null  object
#  12  Instrumentalness  20716 non-null  object
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %% [markdown]
#         2.8. ¿Cuántos valores nulos tenemos por columna?

# %%
df.isna().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
#         2.9. ¿Tenemos filas duplicadas en el dataframe ?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#         2.10. Muestra los principales estadísticos para las columnas numéricas del dataframe

# %%
df.describe().T
# Out:
#                count          mean           std         min           25%  \
# Liveness     20716.0  1.935210e-01  1.685309e-01      0.0145  9.410000e-02
# Valence      20716.0  5.298533e-01  2.454408e-01      0.0000  3.390000e-01
# Tempo        20716.0  1.206383e+02  2.957902e+01      0.0000  9.700200e+01
# Duration_ms  20716.0  2.247176e+05  1.247905e+05  30985.0000  1.800095e+05
# Views        20248.0  9.393782e+07  2.746443e+08      0.0000  1.826002e+06
# Likes        20177.0  6.633411e+05  1.789324e+06      0.0000  2.158100e+04
# Comments     20149.0  2.751899e+04  1.932347e+05      0.0000  5.090000e+02
# Stream       20142.0  1.359422e+08  2.441321e+08   6574.0000  1.767486e+07
#
#                       50%           75%           max
# Liveness     1.250000e-01  2.370000e-01  1.000000e+00
# Valence      5.370000e-01  7.262500e-01  9.930000e-01
# Tempo        1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms  2.132845e+05  2.524430e+05  4.676058e+06
# ...

# %% [markdown]
#         2.11. Muestra los principales estadísticos para las columnas categóricas del dataframe

# %%
df.describe(include= object).T
# Out:
#                   count unique  \
# Artist            20718   2079
# Url_spotify       20718   2079
# Track             20718  17841
# Album             20718  11937
# Album_type        20718      3
# Uri               20718  18862
# Danceability      20716    898
# Energy            20716   1268
# Key               20716     12
# Loudness          20716   9417
# Speechiness       20716   1303
# Acousticness      20716   3138
# Instrumentalness  20716   4012
# Url_youtube       20248  18154
# Title             20248  18146
# Channel           20248   6714
# Description       19842  17395
# Licensed          20248      2
# Official_video    20248      2
#
#                                                                 top   freq
# Artist                                                     Gorillaz     10
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...     10
# Track                     El Ultimo Adiós - Varios Artistas Version     24
# ...

# %%
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'Official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
#     3. Preparación de los datos:
#         3.1. Los nombres de las columnas empiezan con mayúsculas, poned todos los nombres de las columnas en minúsculas.

# %%
def cambiar_columnas (df):
    columnas_nuevas_df = {col :  col.lower() for col in df.columns}
    df.rename(columns = columnas_nuevas_df, inplace = True)

# %%
cambiar_columnas(df)

# %%
df.head(1)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             track       album album_type  \
# 0  Feel Good Inc.  Demon Days      album
#
#                                     uri danceability energy  key loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705  6,0   -6,679
#
#   speechiness acousticness instrumentalness  liveness  valence    tempo  \
# 0       0,177      0,00836          0,00233     0.613    0.772  138.559
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         title   channel        views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
# ...

# %% [markdown]
#         3.2. Haciendo el análisis exploratorio nos deberíamos haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Cread una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.

# %%
df.dtypes
# Out:
# artist               object
# url_spotify          object
# track                object
# album                object
# album_type           object
# uri                  object
# danceability         object
# energy               object
# key                  object
# loudness             object
# speechiness          object
# acousticness         object
# instrumentalness     object
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# url_youtube          object
# title                object
# channel              object
# views               float64
# likes               float64
# comments            float64
# description          object
# licensed             object
# official_video       object
# stream              float64
# dtype: object

# %%
def cambiar_coma_punto (df):
    for col in df.columns:
        if df[col].dtype == object:
            try: 
                df[col] = df[col].str.replace(",", ".")
            except:
                pass
        elif df[col].dtype != object:
            pass

# %%
cambiar_coma_punto(df)

# %%
df.head()
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            album album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
df.dtypes
# Out:
# artist               object
# url_spotify          object
# track                object
# album                object
# album_type           object
# uri                  object
# danceability         object
# energy               object
# key                  object
# loudness             object
# speechiness          object
# acousticness         object
# instrumentalness     object
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# url_youtube          object
# title                object
# channel              object
# views               float64
# likes               float64
# comments            float64
# description          object
# licensed             object
# official_video       object
# stream              float64
# dtype: object

# %% [markdown]
#             3.2.1. Después de haber hecho los cambios, chequead los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, cread otra función o modificar la anterior para que sean de tipo float.

# %% [markdown]
# danceability, energy, key, loudness, speechiness, acousticness, instrumentalness

# %%
def cambiar_tipo (df):
    for col in df.columns:
        if df["danceability"].dtype == object:
            df["danceability"]= df["danceability"].astype(float)
        elif df["energy"].dtype == object:
            df["energy"]= df["energy"].astype(float)
        elif df["key"].dtype == object:
            df["key"]= df["key"].astype(float)
        elif df["loudness"].dtype == object:
            df["loudness"]= df["loudness"].astype(float)
        elif df["speechiness"].dtype == object:
            df["speechiness"]= df["speechiness"].astype(float)
        elif df["acousticness"].dtype == object:
            df["acousticness"]= df["acousticness"].astype(float)
        elif df["instrumentalness"].dtype == object:
            df["instrumentalness"]= df["instrumentalness"].astype(float)
        else:
            pass

# %%
cambiar_tipo(df)

# %% [markdown]
#         3.3. Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haced lo mismo para las columnas de "track" y "album".

# %%
def cambiar_minus (titulo):
    if isinstance(titulo, str):
        return titulo.lower()
    else:
        return titulo

# %%
df["title"] = df["title"].apply(cambiar_minus)
df["track"] = df["track"].apply(cambiar_minus)
df["album"] = df["album"].apply(cambiar_minus)

# %%
df.sample(5)
# Out:
#                    artist                                        url_spotify  \
# 9765   Natalia Lafourcade  https://open.spotify.com/artist/1hcdI2N1023RvS...
# 15564       Natti Natasha  https://open.spotify.com/artist/1GDbiv3spRmZ1X...
# 19629       The Kid LAROI  https://open.spotify.com/artist/2tIP7SsRs7vjIc...
# 17383       Sfera Ebbasta  https://open.spotify.com/artist/23TFHmajVfBtlR...
# 17417    Maiara & Maraisa  https://open.spotify.com/artist/59jlthNnbmim5l...
#
#                                                    track  \
# 9765                                      ella es bonita
# 15564                                      no me acuerdo
# 19629                                        without you
# 17383                                          bang bang
# 17417  nem namorado e nem ficante - ao vivo | faixa b...
#
#                                                  album album_type  \
# 9765                                          hu hu hu      album
# ...

# %% [markdown]
#         3.4. Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Cread una función que nos elimine este símbolo de los nombres de los artistas.

# %%
""" def cambiar_dolar (nombre):
    if isinstance(nombre, str):
        return nombre.replace("$", "")
    else:
        return nombre """
# Out:
# ' def cambiar_dolar (nombre):\n    if isinstance(nombre, str):\n        return nombre.replace("$", "")\n    else:\n        return nombre '

# %%
df["artist"] = df["artist"].apply(cambiar_dolar)

# %%
df["artist"].sample(50)
# Out:
# 1387                          Alesso
# 3667                            UB40
# 16577                Dawid Podsiadło
# 13290                  Sean Kingston
# 4360                             Eve
# 18353                   Montell Fish
# 3456     Los Invasores De Nuevo León
# 7180                   Thomas Newman
# 6805           Engenheiros Do Hawaii
# 6278                Barbra Streisand
# 7480                    Serdar Ortaç
# 7826                   Hector & Tito
# 1036                          Eagles
# 16289                       Galantis
# 7195                   Alceu Valença
# 3684                     Duran Duran
# 14155                 Ellie Goulding
# 2013               The White Stripes
# 15876                  WALK THE MOON
# 1376             Marco Antonio Solís
# 5362                    James Horner
# 2572                          Coolio
# 12881                  Nipsey Hussle
# 7841             The Pointer Sisters
# 1207                         Juicy J
# ...

# %% [markdown]
#     4. Filtrado de datos y Visualización:
#         4.1. ¿Cuáles son los valores únicos de la columna "album_type"? Cread tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
df["album_type"].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
df_album = df[df["album_type"].isin(["album"])]
df_single = df[df["album_type"].isin(["single"])]
df_compilation = df[df["album_type"].isin(["compilation"])]

# %%
df_album["album_type"].unique()
# Out:
# array(['album'], dtype=object)

# %%
df_single["album_type"].unique()
# Out:
# array(['single'], dtype=object)

# %%
df_compilation["album_type"].unique()
# Out:
# array(['compilation'], dtype=object)

# %%
df_album.shape
print(f"En este dataframe: df_album tenemos {df_album.shape[0]} canciones")
# Out:
# En este dataframe: df_album tenemos 14926 canciones

# %%
df_single.shape
print(f"En este dataframe: df_single tenemos {df_single.shape[0]} canciones")
# Out:
# En este dataframe: df_single tenemos 5004 canciones

# %%
df_compilation.shape
print(f"En este dataframe: df_compilation tenemos {df_compilation.shape[0]} canciones")
# Out:
# En este dataframe: df_compilation tenemos 788 canciones

# %%
df.shape
# Out:
# (20718, 27)

# %% [markdown]
#         4.2. Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Mostrad los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordenar los resultados de mayor a menor en base a la media.

# %%
df_danceability = df_album.groupby('artist')['danceability'].agg(['mean', 'std']).sort_values(by = 'mean', ascending=False)
df_acousticness = df_album.groupby('artist')['acousticness'].agg(['mean', 'std']).sort_values(by = 'mean', ascending=False)
df_speechiness = df_album.groupby('artist')['speechiness'].agg(['mean', 'std']).sort_values(by = 'mean', ascending=False)

# %%
df_danceability.head()
# Out:
#                mean       std
# artist
# Latto      0.922333  0.014503
# Murda      0.911500  0.030406
# Jon Z      0.886000  0.015556
# Blueface   0.885000  0.043782
# Jung Kook  0.881000       NaN

# %%
df_acousticness.head()
# Out:
#                      mean       std
# artist
# Claude Debussy   0.993714  0.001380
# Robert Schumann  0.993444  0.004902
# Franz Schubert   0.989500  0.005237
# Edvard Grieg     0.989500  0.007863
# Frédéric Chopin  0.989286  0.004071

# %%
df_speechiness.head()
# Out:
#                           mean       std
# artist
# Sir Arthur Conan Doyle  0.9523  0.008845
# Bibi Blocksberg         0.9453  0.011879
# Sherlock Holmes         0.9393  0.015833
# TKKG                    0.9193  0.023542
# Fünf Freunde            0.9062  0.048960

# %% [markdown]
#         4.3. Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, querremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#             4.3.1. Agrupar por artista y calcular la media de visitas y de likes.

# %%
df_likes = df.groupby('artist')["views", "likes"].mean()
# Out:
# /tmp/ipykernel_9755/1077926423.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_likes = df.groupby('artist')["views", "likes"].mean()

# %% [markdown]
#             4.3.2. Quedaros con los 10 artistas que más visitas han tenido.

# %%
top10_views = df_likes.nlargest(10, 'views')

# %%
top10_views
# Out:
#                                 views      likes
# artist
# Ed Sheeran               1.546021e+09  8354331.9
# CoComelon                1.460167e+09  4171391.3
# Katy Perry               1.312063e+09  6306709.0
# Charlie Puth             1.216759e+09  8633692.5
# Luis Fonsi               1.162811e+09  6690848.9
# Justin Bieber            1.099106e+09  7858434.8
# Daddy Yankee             1.087193e+09  6551817.1
# Bruno Mars               1.024092e+09  5961614.6
# Macklemore & Ryan Lewis  1.012206e+09  6604141.0
# Coldplay                 9.997278e+08  6315789.5

# %% [markdown]
# Con el sort values nos saca dos índices, PREGUNTAR

# %%
df_views10 = df_likes.sort_values(("views"), ascending = False)

# %%
df_top_views = df_likes10.head(10)
df_top_views
# Out:
#                         views       likes
#                          mean        mean
# artist
# BTS              5.607867e+08  13940380.8
# BLACKPINK        9.392962e+08  13230250.5
# Charlie Puth     1.216759e+09   8633692.5
# Ed Sheeran       1.546021e+09   8354331.9
# Justin Bieber    1.099106e+09   7858434.8
# Billie Eilish    4.821569e+08   7333853.7
# Imagine Dragons  9.093785e+08   7227447.7
# Alan Walker      7.256847e+08   6797770.2
# DJ Snake         9.180268e+08   6777583.1
# Luis Fonsi       1.162811e+09   6690848.9

# %% [markdown]
#             4.3.3. Quedaros con los 10 artistas que más likes han tenido.

# %%
top10_likes = df_likes.nlargest(10, 'likes')

# %%
top10_likes
# Out:
#                         views       likes
# artist
# BTS              5.607867e+08  13940380.8
# BLACKPINK        9.392962e+08  13230250.5
# Charlie Puth     1.216759e+09   8633692.5
# Ed Sheeran       1.546021e+09   8354331.9
# Justin Bieber    1.099106e+09   7858434.8
# Billie Eilish    4.821569e+08   7333853.7
# Imagine Dragons  9.093785e+08   7227447.7
# Alan Walker      7.256847e+08   6797770.2
# DJ Snake         9.180268e+08   6777583.1
# Luis Fonsi       1.162811e+09   6690848.9

# %% [markdown]
#             4.4.4. Haced un subplot, donde en uno tengamos los 10 artistas con más likes y en el otro los 10 artistas con mas views.

# %%
import matplotlib.pyplot as plt

# %%
top10_views 
top10_likes

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 10))
fig.suptitle('Relación entre visitas y likes por artista')

# Gráfico de barras para los 10 artistas con más visitas
ax1.bar(top10_views.index, top10_views['views'], color='blue')
ax1.set_title('Top 10 artistas con más visitas')
ax1.set_xlabel('Artist')
ax1.set_ylabel('Views')

# Gráfico de barras para los 10 artistas con más likes
ax2.bar(top10_likes.index, top10_likes['likes'], color='red')
ax2.set_title('Top 10 artistas con más likes')
ax2.set_xlabel('Artist')
ax2.set_ylabel('Likes')

plt.show()

# %% [markdown]
#             4.4.5. BONUS Haced lo mismo para los datos de tipo "single".

# %%
df_single2 = df_single.groupby('artist')["views", "likes"].mean()
# Out:
# /tmp/ipykernel_9755/4213560291.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_single2 = df_single.groupby('artist')["views", "likes"].mean()

# %%
top10_views2 = df_single2.nlargest(10, 'views')
top10_likes2 = df_single2.nlargest(10, 'likes')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 10))
fig.suptitle('Relación entre visitas y likes por artista')

# Gráfico de barras para los 10 artistas con más visitas
ax1.bar(top10_views2.index, top10_views2['views'], color='green')
ax1.set_title('Top 10 artistas con más visitas del Dataframe Singles')
ax1.set_xlabel('Artist')
ax1.set_ylabel('Views')

# Gráfico de barras para los 10 artistas con más likes
ax2.bar(top10_likes2.index, top10_likes2['likes'], color='orange')
ax2.set_title('Top 10 artistas con más likes del Dataframe Singles')
ax2.set_xlabel('Artist')
ax2.set_ylabel('Likes')

plt.show()

# %% [markdown]
#         4.4. Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años. Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un ranking con los diez primeros. ¿Qué artistas con los que más colaboraciones tienen? Para esto tendréis que:
#             4.4.1. Filtrad los datos para quedaros solo con aquellos datos donde en la columna "track" tengamos "feat".

# %%
df_colab = df[df["track"].str.contains("feat",case = True)]

# %%
df_colab.head()
# Out:
#       artist                                        url_spotify  \
# 2   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 27   50 Cent  https://open.spotify.com/artist/3q7HBObVc0L8jN...
#
#                                                 track  \
# 2       new gold (feat. tame impala and bootie brown)
# 6   new gold (feat. tame impala and bootie brown) ...
# 7                  she's my collar (feat. kali uchis)
# 8                   cracker island (feat. thundercat)
# 27                 is this love ('09) (feat. 50 cent)
#
#                                                 album album_type  \
# 2       new gold (feat. tame impala and bootie brown)     single
# 6   new gold (feat. tame impala and bootie brown) ...     single
# ...

# %% [markdown]
#             4.4.2. Contad cuantas canciones tiene cada artista utilizando el dataframe generado en el paso anterior.

# %%
df_canciones = df_colab.groupby("artist")["track"].count()

# %%
df_canciones = pd.DataFrame(df_canciones)

# %%
df_canciones
# Out:
#                    track
# artist
# 070 Shake              1
# 112                    4
# 1nonly                 1
# 2 Chainz               1
# 21 Savage              2
# ...                  ...
# keshi                  1
# sped up nightcore      1
# thasup                 8
# Ñejo                   1
# Ñengo Flow             1
#
# [702 rows x 1 columns]

# %% [markdown]
#             4.4.3. Mostrad los resultados en una gráfica, seleccionado los 10 artistas con más colaboraciones.

# %%
top10_canciones = df_canciones.nlargest(10, 'track')

# %%
top10_canciones = top10_canciones.reset_index()

# %%
top10_canciones
# Out:
#                     artist  track
# 0            Bibi und Tina     10
# 1                  Juicy J     10
# 2               Macklemore     10
# 3                DJ Khaled      9
# 4             Ty Dolla ign      9
# 5             Wu-Tang Clan      9
# 6                    B.o.B      8
# 7             Clean Bandit      8
# 8  Macklemore & Ryan Lewis      8
# 9              Mark Ronson      8

# %%
import seaborn as sns

# %%
sns.barplot(x='track', y = "artist",  data = top10_canciones)
# Out:
# <AxesSubplot:xlabel='track', ylabel='artist'>

# %% [markdown]
#             4.4.4. Deberéis contestar a las siguientes preguntas:
#                 - ¿Cuáles son los diez artistas que más han colaborado según los datos que tenemos?

# %% [markdown]
# Los artistas que más han colaborado son:
#
# - 1º. Bibi und Tina con 10 colaboraciones
# - 2º. Juicy J	con 10 colaboraciones
# - 3º. Macklemore con 10 colaboraciones
# - 4º. DJ Khaled con 9 colaboraciones
# - 5º. Ty Dolla ign con 9 colaboraciones
# - 6º. Wu-Tang Clan con 9 colaboraciones
# - 7º. B.o.B con 8 colaboraciones
# - 8º. Clean Bandit con 8 colaboraciones
# - 9º. Macklemore & Ryan Lewis	con 8 colaboraciones
# - 10º. Mark Ronson con 8 colaboraciones

# %% [markdown]
#                 - ¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el ranking?

# %% [markdown]
# El número de canciones es 10.

# %% [markdown]
#                 - ¿Cuál es el artista que ocupa el décimo lugar en el ranking y en cuántas canciones ha colaborado?

# %% [markdown]
# El artista es Mark Ronson con un total de 8 colaboraciones.

# %% [markdown]
#         4.5. Utilizando el dataframe original, queremos explorar si el tipo de álbum influye en la cantidad de vistas que recibe en una plataforma de transmisión de música. Para ello, debemos generar un boxplot con las variables necesarias y responder las siguientes preguntas:
#             4.5.1. ¿Qué tipo de álbumes tienden a tener más vistas en promedio?

# %%
sns.boxplot(data = df, x = df["views"], y = df["album_type"])
# Out:
# <AxesSubplot:xlabel='views', ylabel='album_type'>

# %% [markdown]
# Los álbumes de tipo álbum reciben mas visitas.

# %% [markdown]
#             4.5.2. ¿Hay algún tipo de álbumes que tenga una mayor dispersión en las vistas recibidas?

# %%
df_album = df.groupby('album_type')["views"].agg(["mean", "std", "median", "var", "max", "min"])

# %%
df_album.reset_index()
# Out:
#     album_type          mean           std      median           var  \
# 0        album  9.842739e+07  2.858933e+08  15781710.0  8.173497e+16
# 1  compilation  7.961832e+07  2.196741e+08   9569629.0  4.825673e+16
# 2       single  8.269886e+07  2.461023e+08  11324830.0  6.056635e+16
#
#             max   min
# 0  8.079649e+09   0.0
# 1  3.463816e+09  71.0
# 2  5.773798e+09  28.0

# %% [markdown]
# Los que tienen mayor dispersión son los de tipo álbum.

# %% [markdown]
#             4.5.3. ¿Existen valores atípicos (outliers) en alguna categoría de álbumes?

# %% [markdown]
# Todas las categorías tienen outliers, lo que quiere decir que hay pocos datos con muchísimas visualizaciones.

# %% [markdown]
#             4.5.4. ¿Qué conclusión se puede obtener sobre la relación entre el tipo de álbum y la cantidad de vistas recibidas?

# %% [markdown]
# Los de tipo álbum son los que tienen mayor cantidad de visitas, la media de visitas más alta y a su vez mayor dispersión de los datos, ya que tiene los outliers más altos, que puede ser que nos estén variando las variables estadísticas.
# Podríamos estudiar este conjunto de datos dividiéndolo en dos grupos para obtener mejores resultados, por un lado, los que tienen hasta 200.000 visitas aproximadamente y por el otro, las que tienen más de esta cifra; así podríamos ver con más claridad la relación entre los tipos de álbum.
